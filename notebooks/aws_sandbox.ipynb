# %%
import boto3

# %%
s3 = boto3.client("s3")

# %%
credentials = {"accessKeyId": "ASIAZLX6ZES4WQZPTW2N",
 "secretAccessKey": "cUVlj5BNtZ8ycpA2ZMAfjVTu6o0Rz056FKnz1256",
 "sessionToken": "...",
 "expiration": "2023-02-10 04:58:13+00:00"}

# %%
url = 's3://lp-prod-protected/HLSS30.020/HLS.S30.T15TXE.2023038T165449.v2.0/HLS.S30.T15TXE.2023038T165449.v2.0.B03.tif'

# %%
s3.download_file(
    Bucket="lp-prod-protected", Key="train.csv",
    Filename="../Data/HLS.S30.T15TXE.2023038T165449.v2.0.B03.tif"
)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 s3.download_file(
#       2     Bucket="sample-bucket-1801", Key="train.csv",
#       3     Filename="../Data/HLS.S30.T15TXE.2023038T165449.v2.0.B03.tif"
#       4 )
#
# File ~\anaconda3\lib\site-packages\boto3\s3\inject.py:190, in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     155 """Download an S3 object to a file.
#     156
#     157 Usage::
#    (...)
#     187     transfer.
#     188 """
#     189 with S3Transfer(self, Config) as transfer:
# --> 190     return transfer.download_file(
#     191         bucket=Bucket,
#     192         key=Key,
#     193         filename=Filename,
#     194         extra_args=ExtraArgs,
#     195         callback=Callback,
#     196     )
#
# ...
